# %% [markdown]
# # Telco Customer Churn IBM Dataset Using LightGBM and Deep Learning and comparing the results

# %% [markdown]
# **Customer churn** is a financial term that refers to the loss of a client or customer—that is, when a customer ceases to interact with a company or business. Similarly, the churn rate is the rate at which customers or clients are leaving a company within a specific period of time. A churn rate higher than a certain threshold can have both tangible and intangible effects on a company's business success. Ideally, companies like to retain as many customers as they can.

# %% [markdown]
# # LightGBM

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Get the Data

# %% [markdown]
# Data source: https://www.kaggle.com/yeanzc/telco-customer-churn-ibm-dataset

# %%
# # load and preview data

# df = pd.read_excel('Telco_customer_churn.xlsx')

# df.head()

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/Colab Notebooks/Telco_customer_churn.xlsx'

import pandas as pd
df = pd.read_excel(file_path)

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# ...

# %%
# view summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
# Drop columns which are not required for model building
df.drop(['Churn Label', 'Churn Score', 'CLTV', 'Churn Reason'], axis=1, inplace=True)

# %%
df['Count'].unique()
# Out:
# array([1])

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['California'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Los Angeles', 'Beverly Hills', 'Huntington Park', ..., 'Standish',
#        'Tulelake', 'Olympic Valley'], dtype=object)

# %%
# Drop more columns
df.drop(['CustomerID', 'Count', 'Country', 'State', 'Lat Long'], axis=1, inplace=True)

df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df['City'].replace(' ', '_', regex=True, inplace=True)

df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df['City'].unique()[0:10]
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', 'Lynwood',
#        'Marina_Del_Rey', 'Inglewood', 'Santa_Monica', 'Torrance',
#        'Whittier', 'La_Habra'], dtype=object)

# %%
# Convert column names too
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['City', 'Zip_Code', 'Latitude', 'Longitude', 'Gender', 'Senior_Citizen',
#        'Partner', 'Dependents', 'Tenure_Months', 'Phone_Service',
#        'Multiple_Lines', 'Internet_Service', 'Online_Security',
#        'Online_Backup', 'Device_Protection', 'Tech_Support', 'Streaming_TV',
#        'Streaming_Movies', 'Contract', 'Paperless_Billing', 'Payment_Method',
#        'Monthly_Charges', 'Total_Charges', 'Churn_Value'],
#       dtype='object')

# %%
# Columns type
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df['Phone_Service'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Total_Charges'].unique()
# Out:
# array([108.15, 151.65, 820.5, ..., 7362.9, 346.45, 6844.5], dtype=object)

# %%
# See how many occurrences
len(df.loc[df['Total_Charges']==' '])
# Out:
# 11

# %%
# Let's look them
df.loc[df['Total_Charges']==' ']
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
# Set the 'Total_Charges' to 0 in these 11 cases, ' ' to zero.

df.loc[(df['Total_Charges']==' '), 'Total_Charges'] = 0

# %%
# Check
len(df.loc[df['Total_Charges']==' '])
# Out:
# 0

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])

df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %%
# Now, let's do the same for All DataFrame.

df.replace(' ', '_', regex=True, inplace=True)

df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ### Split the Data

# %%
X = df.drop('Churn_Value', axis=1).copy()

y = df['Churn_Value'].copy()

# %%
df['Payment_Method'].unique()
# Out:
# array(['Mailed_check', 'Electronic_check', 'Bank_transfer_(automatic)',
#        'Credit_card_(automatic)'], dtype=object)

# %%
#set df view to show all columns
pd.set_option('display.max_columns', None)

# %%
# One-Hot Encoding View
pd.get_dummies(X, columns=['Payment_Method']).head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service Multiple_Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
# 2      No        Yes              8           Yes            Yes
# 3     Yes        Yes             28           Yes            Yes
# 4      No        Yes             49           Yes            Yes
#
#   Internet_Service Online_Security Online_Backup Device_Protection  \
# 0              DSL             Yes           Yes                No
# ...

# %%
X.columns
# Out:
# Index(['City', 'Zip_Code', 'Latitude', 'Longitude', 'Gender', 'Senior_Citizen',
#        'Partner', 'Dependents', 'Tenure_Months', 'Phone_Service',
#        'Multiple_Lines', 'Internet_Service', 'Online_Security',
#        'Online_Backup', 'Device_Protection', 'Tech_Support', 'Streaming_TV',
#        'Streaming_Movies', 'Contract', 'Paperless_Billing', 'Payment_Method',
#        'Monthly_Charges', 'Total_Charges'],
#       dtype='object')

# %%
# shape
X.shape
# Out:
# (7043, 23)

# %%
# number of unique values in each object column
X.select_dtypes('object').nunique()
# Out:
# City                 1129
# Gender                  2
# Senior_Citizen          2
# Partner                 2
# Dependents              2
# Phone_Service           2
# Multiple_Lines          3
# Internet_Service        3
# Online_Security         3
# Online_Backup           3
# Device_Protection       3
# Tech_Support            3
# Streaming_TV            3
# Streaming_Movies        3
# Contract                3
# Paperless_Billing       2
# Payment_Method          4
# dtype: int64

# %%
#drop City
X.drop('City', axis=1, inplace=True)

# %%
# Let's do it for all qualitative columns

X_encoded = pd.get_dummies(X, columns=[
                                       'Gender',
                                       'Senior_Citizen',
                                       'Partner',
                                       'Dependents',
                                       'Phone_Service',
                                       'Multiple_Lines',
                                       'Internet_Service',
                                       'Online_Security',
                                       'Online_Backup',
                                       'Device_Protection',
                                       'Tech_Support',
                                       'Streaming_TV',
                                       'Streaming_Movies',
                                       'Contract',
                                       'Paperless_Billing',
                                       'Payment_Method'])
X_encoded.head()
# Out:
#    Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003  33.964131 -118.272783              2            53.85
# 1     90005  34.059281 -118.307420              2            70.70
# 2     90006  34.048013 -118.293953              8            99.65
# 3     90010  34.062125 -118.315709             28           104.80
# 4     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  Gender_Female  Gender_Male  Senior_Citizen_No  \
# 0         108.15              0            1                  1
# 1         151.65              1            0                  1
# 2         820.50              1            0                  1
# 3        3046.05              1            0                  1
# 4        5036.30              0            1                  1
#
#    Senior_Citizen_Yes  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 0                   0           1            0              1               0
# ...

# %%
# Verify 'y'
y.unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### Build the LightGBM Model

# %%
# Lets see how imbalance is this dataset looking for y=1:
sum(y) / len(y)
# Out:
# 0.2653698707936959

# %%
# Split the trains and tests
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=42, stratify=y)

# %%
# Let's see if stratify worked as expected, creating groups with the same proportion of 1's and 0's.

print(sum(y_train) / len(y_train))
print(sum(y_test) / len(y_test))
# Out:
# 0.2654297614539947
# 0.26519023282226006

# %%
# target class distribution
print('y_train class distribution')
print(y_train.value_counts(normalize=True))
# Out:
# y_train class distribution
# 0    0.73457
# 1    0.26543
# Name: Churn_Value, dtype: float64

# %%
# Prepare the datasets for LightGBM
d_train = lgb.Dataset(X_train, label=y_train)
d_test = lgb.Dataset(X_test, label=y_test, reference=d_train)

# Parameters
params = {
    'objective': 'binary',
    'metric': 'binary_error', # Use binary_error to optimize for accuracy
    'verbose': -1, # Use -1 to suppress verbose output, 1 for verbose output
    'seed': 42
}

early_stopping = lgb.early_stopping(stopping_rounds=50)

# Training
clf_lgb = lgb.train(params,
                    d_train,
                    num_boost_round=1000,
                    valid_sets=[d_test])

# %% [markdown]
# LightGBM's predict method returns the raw scores by default, which need to be converted into binary labels (0 or 1) for your classification threshold (usually 0.5 for binary classification).

# %%
# Predictions - LightGBM outputs probabilities by default
y_pred_prob = clf_lgb.predict(X_test)
# Convert probabilities to binary predictions based on a 0.5 threshold
y_pred = np.where(y_pred_prob > 0.5, 1, 0)

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay instance
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Did not leave', 'Left'])

# Plot the confusion matrix
disp.plot(values_format='d')
plt.show()

# %%
# Accuracy
accuracy_score(y_test, y_pred)
# Out:
# 0.7796706416808632

# %% [markdown]
# ## Now Implementing neural network using pytorch

# %% [markdown]
# ## Neural Net Architecture

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import os

# Define the network
class BinaryClassifier(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2):
        super(BinaryClassifier, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size1)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(hidden_size1, hidden_size2)
        self.output_layer = nn.Linear(hidden_size2, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.layer1(x))
        x = self.relu(self.layer2(x))
        x = self.sigmoid(self.output_layer(x))
        return x

# Convert data to PyTorch tensors
X_train_tensor = torch.from_numpy(X_train.values.astype(np.float32))
y_train_tensor = torch.from_numpy(y_train.values.astype(np.float32)).unsqueeze(1)
X_test_tensor = torch.from_numpy(X_test.values.astype(np.float32))
y_test_tensor = torch.from_numpy(y_test.values.astype(np.float32)).unsqueeze(1)

print('Tensor formed for X_train:', X_train_tensor.shape)
print('Tensor formed for y_train:', y_train_tensor.shape)
print('Tensor formed for X_test:', X_test_tensor.shape)
print('Tensor formed for y_test:', y_test_tensor.shape)

# Create TensorDatasets and DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

print('Train dataset:', len(train_dataset))
print('Test dataset:', len(test_dataset))

batch_size = 100  # You can adjust this
num_workers = os.cpu_count()  # Use all available CPU cores
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

print('Train loader:', len(train_loader))
print('Test loader:', len(test_loader))


# Initialize the model
input_size = X_train.shape[1]
hidden_size1 = 100
hidden_size2 = 50
model = BinaryClassifier(input_size, hidden_size1, hidden_size2)

print('model initialized')

# Loss and optimizer
criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for binary classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Learning rate can be adjusted

print('criterion and optimizer initialized')

# Number of epochs
epochs = 50  # Adjust as needed

for epoch in range(epochs):
    for inputs, labels in train_loader:
        # Forward pass
        # print("in forward pass of epoch:", epoch+1)
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    if (epoch+1)%10==0:
      print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# Tensor formed for X_train: torch.Size([5282, 49])
# Tensor formed for y_train: torch.Size([5282, 1])
# Tensor formed for X_test: torch.Size([1761, 49])
# Tensor formed for y_test: torch.Size([1761, 1])
# Train dataset: 5282
# Test dataset: 1761
# Train loader: 53
# Test loader: 18
# model initialized
# criterion and optimizer initialized
# Epoch [10/50], Loss: 24.3902
# Epoch [20/50], Loss: 25.6098
# Epoch [30/50], Loss: 20.7317
# Epoch [40/50], Loss: 24.3902
# Epoch [50/50], Loss: 24.3902

# %%
 # Evaluate the model on the test set
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    test_loss = 0
    for inputs, labels in test_loader:
        outputs = model(inputs)
        test_loss += criterion(outputs, labels).item()

        # Convert output probabilities to predicted class (0 or 1)
        predicted = torch.round(outputs)

        # Update total and correct predictions
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    test_loss /= len(test_loader)
    accuracy = correct / total

    print(f'Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Loss: 26.5483
# Test Accuracy: 0.7348

# %% [markdown]
# # Conclusion: Predicting Customer Churn with LightGBM and Deep Learning
#
# In conclusion, for the task of predicting customer churn, two different modeling approaches were explored: LightGBM and a deep learning feed-forward neural network.
#
# ## LightGBM Performance
# The LightGBM model demonstrated superior performance in terms of both accuracy and computational efficiency. It achieved an accuracy of 0.7797 on the given dataset and completed the training and prediction process in under 10 seconds using a vanilla model. This highlights the effectiveness of LightGBM as a gradient boosting framework, which is known for its fast training speed and ability to handle large-scale datasets.
#
# ## Deep Learning Model Performance
# On the other hand, the deep learning model, implemented as a feed-forward neural network, encountered challenges when running on a CPU machine. Due to its computational requirements, the model necessitated the use of a GPU, which was facilitated through Google Colab. Despite the utilization of GPU resources, the deep learning model obtained a lower accuracy of 0.7348 and took more than 1 minute to train and evaluate.
#
# ## Comparison and Insights
# These results suggest that for the specific task of predicting customer churn, LightGBM proved to be a more efficient and accurate choice compared to the deep learning approach. Its ability to deliver high accuracy while maintaining fast training times makes it a preferred option, especially when computational resources are limited.
#
# However, it is important to note that the performance of machine learning models can vary depending on the dataset, feature engineering, and hyperparameter tuning. Further experimentation and optimization of both models could potentially lead to improved results.
#
# ## Summary
# In summary, LightGBM demonstrated superior performance in terms of accuracy and efficiency for predicting customer churn, while the deep learning model faced challenges related to computational requirements and achieved lower accuracy. This highlights the importance of considering various modeling approaches and evaluating their suitability based on the specific problem at hand and the available resources.
